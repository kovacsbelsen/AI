# %% [markdown]
# - **`sales_train.csv`** Rows: 2935849 sales (January 2013 -> Octuber 2015)
#   - **date**: date in format dd/mm/yyyy.
#   - **date_block_num**: a consecutive month number. January 2013 is 0, February 2013 is 1,..., October 2015 is 33
#   - **shop_id**: unique identifier of a shop
#   - **item_id**: unique identifier of a product
#   - **item_price**: current price of an item
#   - **item_cnt_day**: number of products sold. You are predicting a monthly amount of this measure.
# - **`shops.csv`** Rows: 60 shops
#   - **shop_id**
#   - **shop_name**: name of shop (RUSSIAN 🇷🇺)
# - **`items.csv`** Rows: 22170 products
#   - **item_id**
#   - **item_name**: name of item (RUSSIAN 🇷🇺)
#   - **item_category_id**: unique identifier of item category
# - **`item_categories.csv`** Rows: 84 product categories
#   - **item_category_id**
#   - **item_category_name**: name of item category (RUSSIAN 🇷🇺)
# - **`test.csv`** Rows: 214200 pairs combination of (Shop, Item)
#   - **ID**: an Id that represents a (Shop, Item) tuple within the test set
#   - **shop_id**
#   - **item_id**

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import missingno as m
import seaborn as sns
from sklearn.ensemble import IsolationForest
from scipy import stats
import matplotlib as plt

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

from geopy.geocoders import Nominatim

# %% [markdown]
# path = "../../datasets/predict-future-sales/"
#
# train = pd.read_csv(path+"sales_train.csv") # Daily sales  Jan 2013 -> Oct 2015
# shops = pd.read_csv(path+"shops-translated.csv")       # Shops    (60)
# items = pd.read_csv(path+"items-translated.csv")       # Products  (22170)
# oritem = pd.read_csv(path+"items.csv")
# cats  = pd.read_csv(path+"item_categories-translated.csv") # Product categories (84)
# test  = pd.read_csv(path+"test.csv", index_col="ID") # predict November 2015
# sub   = pd.read_csv(path+"sample_submission.csv", index_col="ID")

# %%
Exercise 1: Detect repeted shops
There are 4 repeted shops (8 different shop_ids). Look at the shop_name and find repeated shops. This is important because need to remove duplicated shops in the future.

Please complete this:

Ids of repepeated shop 1: _11___ and _10___
Ids of repepeated shop 2: _39___ and _40___
Ids of repepeated shop 3: _23___ and _24___
Ids of repepeated shop 4: _0__ and __1__

# %%
shops
# Out:
#     shop_id                               shop_name_translated
# 0         0                   Yakutsk Ordzhonikidze, 56 francs
# 1         1                         Yakutsk TC "Central" franc
# 2         2                      Adygea Shopping Center "Mega"
# 3         3                   Balashikha TRK "October-Kinomir"
# 4         4              Volzhsky shopping center "Volga Mall"
# 5         5  Vologda Shopping and Entertainment Center "Mar...
# 6         6                      Voronezh (Plekhanovskaya, 13)
# 7         7                            Voronezh TRC "Maksimir"
# 8         8                      Voronezh TRC City-Park "Grad"
# 9         9                                     Outbound Trade
# 10       10                        Zhukovsky Str. Chkalov 39m?
# 11       11                       Zhukovsky Str. Chkalov 39 m²
# 12       12                              Online shop Emergency
# 13       13                                 Kazan TC "Behetle"
# 14       14                             Kazan TC "ParkHaus" II
# 15       15                           Kaluga TRC "XXI Century"
# 16       16                                    Colosseum "Rio"
# 17       17        Krasnoyarsk Shopping center "Vzletka Plaza"
# 18       18                 Krasnoyarsk Shopping center "June"
# 19       19                              Kursk TC "Pushkinsky"
# 20       20                                      Moscow "Sale"
# 21       21                            Moscow MTRTS "Afi Mall"
# 22       22                                    Moscow Shop С21
# 23       23                   Moscow TC "Budenovskiy" (pav.A2)
# 24       24                   Moscow TC "Budenovskiy" (pav.K7)
# 25       25                                Moscow TRK "Atrium"
# 26       26             Moscow Trade Center "Areal" (Belyaevo)
# 27       27                   Moscow ТЦ "MEGA Belaya Dacha II"
# 28       28                     Moscow ТЦ "MEGA Teply Stan" II
# 29       29               Moscow TC "New Century" (Novokosino)
# 30       30                          Moscow TP TPP "Perlovski"
# 31       31                            Moscow ТЦ "Семеновский"
# 32       32              Moscow Shopping Center "Silver House"
# 33       33                                Mytischi TRK "XL-3"
# 34       34                               N.Novgorod TRC "RIO"
# 35       35          Nizhny Novgorod shopping mall "Fantastic"
# 36       36              Novosibirsk TRC "Gallery Novosibirsk"
# 37       37                              Novosibirsk TC "Mega"
# 38       38                                     Omsk TC "Mega"
# 39       39               RostovNaDon TRK "Megacenter Horizon"
# 40       40       RostovNaDonu TRC "Megacenter Horizon" Island
# 41       41                             RostovNaDonu TC "Mega"
# 42       42                             SPb TC "Nevsky Center"
# 43       43                                   SPb TK "Sennaya"
# 44       44                                 Samara TP "Melody"
# 45       45                               Samara TC "ParkHaus"
# 46       46                             Sergiev Posad TC "7YA"
# 47       47  Surgut shopping and entertainment center "City...
# 48       48                           Tomsk SEC "Emerald City"
# 49       49                               Tyumen SEC "Crystal"
# 50       50                   Tyumen shopping center "Goodwin"
# 51       51               Tyumen Shopping Center "Green Beach"
# 52       52                                   Ufa TC "Central"
# 53       53                                  Ufa TC "Family" 2
# 54       54                                   Khimki ТЦ "Mega"
# 55       55                        Digital warehouse 1C-Online
# 56       56                             Chekhov SEC "Carnival"
# 57       57                          Yakutsk Ordzhonikidze, 56
# 58       58                    Yakutsk Central shopping center
# 59       59                 Yaroslavl Shopping center "Altair"

# %%
gshops = shops.groupby(['shop_name_translated', 'shop_id'])['shop_id'].count()

# %%
gshops
# Out:
# shop_name_translated                                   shop_id
# Adygea Shopping Center "Mega"                          2          1
# Balashikha TRK "October-Kinomir"                       3          1
# Chekhov SEC "Carnival"                                 56         1
# Colosseum "Rio"                                        16         1
# Digital warehouse 1C-Online                            55         1
# Kaluga TRC "XXI Century"                               15         1
# Kazan TC "Behetle"                                     13         1
# Kazan TC "ParkHaus" II                                 14         1
# Khimki ТЦ "Mega"                                       54         1
# Krasnoyarsk Shopping center "June"                     18         1
# Krasnoyarsk Shopping center "Vzletka Plaza"            17         1
# Kursk TC "Pushkinsky"                                  19         1
# Moscow "Sale"                                          20         1
# Moscow MTRTS "Afi Mall"                                21         1
# Moscow Shop С21                                        22         1
# Moscow Shopping Center "Silver House"                  32         1
# Moscow TC "Budenovskiy" (pav.A2)                       23         1
# Moscow TC "Budenovskiy" (pav.K7)                       24         1
# Moscow TC "New Century" (Novokosino)                   29         1
# Moscow TP TPP "Perlovski"                              30         1
# Moscow TRK "Atrium"                                    25         1
# Moscow Trade Center "Areal" (Belyaevo)                 26         1
# Moscow ТЦ "MEGA Belaya Dacha II"                       27         1
# Moscow ТЦ "MEGA Teply Stan" II                         28         1
# Moscow ТЦ "Семеновский"                                31         1
# Mytischi TRK "XL-3"                                    33         1
# N.Novgorod TRC "RIO"                                   34         1
# Nizhny Novgorod shopping mall "Fantastic"              35         1
# Novosibirsk TC "Mega"                                  37         1
# Novosibirsk TRC "Gallery Novosibirsk"                  36         1
# Omsk TC "Mega"                                         38         1
# Online shop Emergency                                  12         1
# Outbound Trade                                         9          1
# RostovNaDon TRK "Megacenter Horizon"                   39         1
# RostovNaDonu TC "Mega"                                 41         1
# RostovNaDonu TRC "Megacenter Horizon" Island           40         1
# SPb TC "Nevsky Center"                                 42         1
# SPb TK "Sennaya"                                       43         1
# Samara TC "ParkHaus"                                   45         1
# Samara TP "Melody"                                     44         1
# Sergiev Posad TC "7YA"                                 46         1
# Surgut shopping and entertainment center "City Mall"   47         1
# Tomsk SEC "Emerald City"                               48         1
# Tyumen SEC "Crystal"                                   49         1
# Tyumen Shopping Center "Green Beach"                   51         1
# Tyumen shopping center "Goodwin"                       50         1
# Ufa TC "Central"                                       52         1
# Ufa TC "Family" 2                                      53         1
# Vologda Shopping and Entertainment Center "Marmalade"  5          1
# Volzhsky shopping center "Volga Mall"                  4          1
# Voronezh (Plekhanovskaya, 13)                          6          1
# Voronezh TRC "Maksimir"                                7          1
# Voronezh TRC City-Park "Grad"                          8          1
# Yakutsk Central shopping center                        58         1
# Yakutsk Ordzhonikidze, 56                              57         1
# Yakutsk Ordzhonikidze, 56 francs                       0          1
# Yakutsk TC "Central" franc                             1          1
# Yaroslavl Shopping center "Altair"                     59         1
# Zhukovsky Str. Chkalov 39 m²                           11         1
# Zhukovsky Str. Chkalov 39m?                            10         1
# Name: shop_id, dtype: int64

# %% [markdown]
# Exercise 2: Pysical vs Online shop
# Create a binary column to determint if the shop is online or not.

# %%
online = shops[shops['shop_name_translated'].str.contains('Online', 'Digital')]

# %%
online
# Out:
#     shop_id         shop_name_translated
# 12       12        Online shop Emergency
# 55       55  Digital warehouse 1C-Online

# %%
shops['online'] = shops['shop_name_translated'].str.contains('Online', 'Digital')

# %% [markdown]
# Exercise 3: Get the cities
# Extract the city name of each shop. Cities apears on the first word of the shop name.

# %%
shops['shop_name_translated'] = shops['shop_name_translated'].astype(str)
shops['shop_name_translated'].dtype
# Out:
# dtype('O')

# %%
def get_shop_name(string):
        string_ret = string.split(" ")[0]
        return (string_ret)
    
shops['City'] = shops['shop_name_translated'].apply(get_shop_name)

# %%
shops.loc[shops.shop_id.isin([9,12,55]), 'City'] = np.nan
shops.loc[shops.shop_id.isin([34]), 'City'] = 'Novgorod'
shops.loc[shops.shop_id.isin([33]), 'City'] = 'Mytishchi'
shops.loc[shops.shop_id.isin([39,40,41]), 'City'] = 'Rostov-On-Don'

# %%
shops
# Out:
# 51       51               Tyumen Shopping Center "Green Beach"         Tyumen
# 52       52                                   Ufa TC "Central"            Ufa
# 53       53                                  Ufa TC "Family" 2            Ufa
# 54       54                                   Khimki ТЦ "Mega"         Khimki
# 55       55                        Digital warehouse 1C-Online            NaN
# 56       56                             Chekhov SEC "Carnival"        Chekhov
# 57       57                          Yakutsk Ordzhonikidze, 56        Yakutsk
# 58       58                    Yakutsk Central shopping center        Yakutsk
# 59       59                 Yaroslavl Shopping center "Altair"      Yaroslavl
#
#     online   Latitude  Longitude
# 0    False  55.750446  37.617494
# 1    False  55.750446  37.617494
# 2    False  55.750446  37.617494
# 3    False  55.750446  37.617494
# 4    False  55.750446  37.617494
# 5    False  55.750446  37.617494
# 6    False  55.750446  37.617494
# 7    False  55.750446  37.617494
# 8    False  55.750446  37.617494
# 9    False  55.750446  37.617494
# 10   False  55.750446  37.617494
# 11   False  55.750446  37.617494
# 12    True  55.750446  37.617494
# 13   False  55.750446  37.617494
# 14   False  55.750446  37.617494
# 15   False  55.750446  37.617494
# 16   False  55.750446  37.617494
# 17   False  55.750446  37.617494
# 18   False  55.750446  37.617494
# 19   False  55.750446  37.617494
# 20   False  55.750446  37.617494
# 21   False  55.750446  37.617494
# 22   False  55.750446  37.617494
# 23   False  55.750446  37.617494
# 24   False  55.750446  37.617494
# 25   False  55.750446  37.617494
# 26   False  55.750446  37.617494
# 27   False  55.750446  37.617494
# 28   False  55.750446  37.617494
# 29   False  55.750446  37.617494
# 30   False  55.750446  37.617494
# 31   False  55.750446  37.617494
# 32   False  55.750446  37.617494
# 33   False  55.750446  37.617494
# 34   False  55.750446  37.617494
# 35   False  55.750446  37.617494
# 36   False  55.750446  37.617494
# 37   False  55.750446  37.617494
# 38   False  55.750446  37.617494
# 39   False  55.750446  37.617494
# 40   False  55.750446  37.617494
# 41   False  55.750446  37.617494
# 42   False  55.750446  37.617494
# 43   False  55.750446  37.617494
# 44   False  55.750446  37.617494
# 45   False  55.750446  37.617494
# 46   False  55.750446  37.617494
# 47   False  55.750446  37.617494
# 48   False  55.750446  37.617494
# 49   False  55.750446  37.617494
# 50   False  55.750446  37.617494
# 51   False  55.750446  37.617494
# 52   False  55.750446  37.617494
# 53   False  55.750446  37.617494
# 54   False  55.750446  37.617494
# 55    True  55.750446  37.617494
# 56   False  55.750446  37.617494
# 57   False  55.750446  37.617494
# 58   False  55.750446  37.617494
# 59   False  55.750446  37.617494

# %% [markdown]
# Exercise 4: Latitude & Longitude
# Get Latitude an Longitude of each city. You can use the geopy package.

# %%
import pandas, os, geopy
from geopy.geocoders import Nominatim


GeoLocator = Nominatim(user_agent="bence")

longitude = []
latitude = []
city_list = []


for city in shops['City']:
    
    if city is None:
        pass
        
        
    else:    
            print(city)
            location = GeoLocator.geocode(query = city)
            print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
            city_list.append(location)
            latitude.append(location.latitude)
            longitude.append(location.longitude)
# Out:
# Yakutsk
# Latitude = 62.027287, Longitude = 129.732086
# Yakutsk
# Latitude = 62.027287, Longitude = 129.732086
# Adygea
# Latitude = 46.370935349999996, Longitude = 6.231168493722434
# Ufa
# Latitude = 46.370935349999996, Longitude = 6.231168493722434
# Khimki
# Latitude = 55.8892847, Longitude = 37.4449896
# nan
# Latitude = 46.3144754, Longitude = 11.0480288
# Chekhov
# Latitude = 55.1426603, Longitude = 37.4545328
# Yakutsk
# Latitude = 62.027287, Longitude = 129.732086
# Yakutsk
# Latitude = 62.027287, Longitude = 129.732086
# Yaroslavl
# Latitude = 57.6263877, Longitude = 39.8933705

# %%
 #shops['Location'] = pd.DataFrame(city_list)
shops['Latitude'] = pd.DataFrame(latitude)
shops['Longitude'] = pd.DataFrame(longitude)

# %%
shops
# Out:
#     shop_id                               shop_name_translated           City  \
# 0         0                   Yakutsk Ordzhonikidze, 56 francs        Yakutsk
# 1         1                         Yakutsk TC "Central" franc        Yakutsk
# 2         2                      Adygea Shopping Center "Mega"         Adygea
# 3         3                   Balashikha TRK "October-Kinomir"     Balashikha
# 4         4              Volzhsky shopping center "Volga Mall"       Volzhsky
# 5         5  Vologda Shopping and Entertainment Center "Mar...        Vologda
# 6         6                      Voronezh (Plekhanovskaya, 13)       Voronezh
# 7         7                            Voronezh TRC "Maksimir"       Voronezh
# 8         8                      Voronezh TRC City-Park "Grad"       Voronezh
# 9         9                                     Outbound Trade            NaN
# 10       10                        Zhukovsky Str. Chkalov 39m?      Zhukovsky
# 11       11                       Zhukovsky Str. Chkalov 39 m²      Zhukovsky
# 12       12                              Online shop Emergency            NaN
# 13       13                                 Kazan TC "Behetle"          Kazan
# 14       14                             Kazan TC "ParkHaus" II          Kazan
# 15       15                           Kaluga TRC "XXI Century"         Kaluga
# 16       16                                    Colosseum "Rio"      Colosseum
# 17       17        Krasnoyarsk Shopping center "Vzletka Plaza"    Krasnoyarsk
# 18       18                 Krasnoyarsk Shopping center "June"    Krasnoyarsk
# 19       19                              Kursk TC "Pushkinsky"          Kursk
# 20       20                                      Moscow "Sale"         Moscow
# 21       21                            Moscow MTRTS "Afi Mall"         Moscow
# 22       22                                    Moscow Shop С21         Moscow
# 23       23                   Moscow TC "Budenovskiy" (pav.A2)         Moscow
# 24       24                   Moscow TC "Budenovskiy" (pav.K7)         Moscow
# 25       25                                Moscow TRK "Atrium"         Moscow
# 26       26             Moscow Trade Center "Areal" (Belyaevo)         Moscow
# 27       27                   Moscow ТЦ "MEGA Belaya Dacha II"         Moscow
# 28       28                     Moscow ТЦ "MEGA Teply Stan" II         Moscow
# 29       29               Moscow TC "New Century" (Novokosino)         Moscow
# 30       30                          Moscow TP TPP "Perlovski"         Moscow
# 31       31                            Moscow ТЦ "Семеновский"         Moscow
# 32       32              Moscow Shopping Center "Silver House"         Moscow
# 33       33                                Mytischi TRK "XL-3"      Mytishchi
# 34       34                               N.Novgorod TRC "RIO"       Novgorod
# 35       35          Nizhny Novgorod shopping mall "Fantastic"         Nizhny
# 36       36              Novosibirsk TRC "Gallery Novosibirsk"    Novosibirsk
# 37       37                              Novosibirsk TC "Mega"    Novosibirsk
# 38       38                                     Omsk TC "Mega"           Omsk
# 39       39               RostovNaDon TRK "Megacenter Horizon"  Rostov-On-Don
